# %% [markdown]
# <a href="https://colab.research.google.com/github/OnyxDude/Machine-Learning-with-python/blob/main/Phase_3_Data_preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Phase 3: Data preparation

# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')

# %%
df.head()
# Out:
#    Number Date (dd/mm/yy) Name of the activity   Cost  Budget  Time invested  \
# 0       1      08/14/2023     Public Transport   50.0   100.0           45.0
# 1       2      08/14/2023          Morning Jog    0.0     0.0           30.0
# 2       3      08/14/2023            Uber Ride   70.0   100.0           20.0
# 3       4      08/14/2023      Online Shopping  250.0   300.0           60.0
# 4       5      08/15/2023   Lunch with Friends  500.0   600.0           60.0
#
#    Type  Moment  No. of people
# 0   6.0     1.0            1.0
# 1   3.0     1.0            1.0
# 2   6.0     2.0            1.0
# 3   4.0     2.0            1.0
# 4   1.0     2.0            4.0

# %%
df = df.iloc[:,3:9]

# %%
df.head()
# Out:
#     Cost  Budget  Time invested  Type  Moment  No. of people
# 0   50.0   100.0           45.0   6.0     1.0            1.0
# 1    0.0     0.0           30.0   3.0     1.0            1.0
# 2   70.0   100.0           20.0   6.0     2.0            1.0
# 3  250.0   300.0           60.0   4.0     2.0            1.0
# 4  500.0   600.0           60.0   1.0     2.0            4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Cost           186 non-null    float64
#  1   Budget         186 non-null    float64
#  2   Time invested  186 non-null    float64
#  3   Type           186 non-null    float64
#  4   Moment         186 non-null    float64
#  5   No. of people  186 non-null    float64
# dtypes: float64(6)
# memory usage: 14.2 KB

# %%
df.isnull().sum()
# Out:
# Cost             114
# Budget           114
# Time invested    114
# Type             114
# Moment           114
# No. of people    114
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['Cost', 'Budget', 'Time invested', 'Type', 'Moment', 'No. of people'], dtype='object')

# %%
x = df[['Budget', 'Time invested', 'Type', 'Moment', 'No. of people']].values # independent variables

y = df['Cost'].values # dependent variable

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
y_test
# Out:
# array([ 200.,   50.,  300.,   50.,   30.,  150., 1200.,   50.,    0.,
#          60., 2000.,  350.,   50.,  100.,    0.,    0.,  250.,  200.,
#         500.,  150.,  800.,  300.,    0.,   50.,  800.,  150.,    0.,
#           0.,    0.,   50.,  500.,    0.,    0.,  300.,    0.,  400.,
#         150.,  200.])

# %% [markdown]
# # **Part 1:**
# In this data preparation and analysis program, we begin by uploading an Excel file into a Google Colab notebook. Using the Pandas library, we read the Excel file and ensure there are no errors during the process. To do this, we create a new code cell for each line of code. We import the Pandas library and assign it to the variable 'pd' by using 'import pandas as pd'. Following this, we create a DataFrame 'df' by reading the Excel file with 'df = pd.read_excel('data.xlsx')' and check the first 5 records with 'df.head()'.
#
#
# The next step involves selecting specific data using 'iloc' based on row and column indices. To ensure we have the necessary numeric values, we inspect the data with 'df.info()'. Any null values are identified using 'df.isnull().sum()', and we remove them with 'df = df.dropna()'.
#
#
# Subsequently, we assign input and output attributes to 'x' and 'y' and split the data into training and test sets using 'train_test_split' from SciKit-Learn. This process prepares the data for machine learning analysis, ensuring it is in a numeric format, clean, and suitable for further modeling in Phase 4.
#
#
# This program's primary objective is to ready the data for analysis. It starts by uploading an Excel file into a Google Colab notebook and utilizes the Pandas library for data manipulation. The initial steps include reading the Excel file and inspecting the first 5 rows to ensure data quality.
#
#
# Following this, the program focuses on data selection and addressing missing values. Any missing values are removed, and data format is verified to contain only numeric values without any extraneous information.
#
#
# The subsequent division of data into training and testing sets is crucial for future predictive analysis. This ensures that the data is appropriately structured for the subsequent analysis steps.
#
#
# In conclusion, this program ensures that the data is clean, well-organized, and ready for further analysis steps.

# %% [markdown]
# # **Part 2:**
# **What data should be selected? Why?**
# In the data selection step, we decide what specific records and attributes (rows and columns) to include in our analysis. The selection of data is critical as it determines the scope of our analysis. For our expense records, we want to choose records that are relevant to our analysis, such as those pertaining to specific activities or time periods. We may also select specific attributes like Cost, Budget, and No. of people to perform analyses.
#
# **Do blank values need to be removed or replaced? Yes / No / Why.**
# Yes, blank values or missing data should be dealt with in the data cleaning step. Incomplete or missing information can lead to inaccurate analysis. Depending on the nature of the missing data and its impact on the analysis, we might choose to either remove rows with missing values or replace them with estimated values. It's essential to handle missing data appropriately to ensure the quality of our analysis.
#
# **Is it possible to add more data? Yes / No / Why.**
# Yes, in the phase of generating new data, we may create additional data to enrich our analysis. For example, we might generate a new column that marks the purchase of an extended warranty for each transaction. Adding more data can provide valuable insights and improve the quality of our analysis.
#
# **Do you need to integrate or merge data from various sources? Yes / No / Why.**
# It depends on the project's objectives. If we have data from multiple sources that contain related information, merging the data can provide a more comprehensive view of the subject. For instance, if we have expense records and demographic data with a common identifier (like social security numbers), merging these datasets can help us analyze expenses in the context of demographics.
#
# **Is it necessary to sort the data for analysis? Yes / No / Why.**
# Sorting the data may be necessary, depending on the analysis techniques and models we plan to use. Some algorithms or methods may require data to be pre-sorted before running the analysis. Additionally, sorting can sometimes optimize processing time. Whether sorting is necessary will depend on the specific requirements of the analysis.
#
# **Do separate data sets have to be made for training and testing? Yes / No / Why.**
# Yes, it's essential to create separate datasets for training and testing. In our case, we use an 80-20 split, where 80% of the data is used for training and 20% for testing. This division allows us to train machine learning models on one portion of the data and then validate their performance on unseen data. It helps assess the model's generalization and ensures that our analysis is robust and accurate.
#
# **What adjustments had to be made to the data (adding, integrating, modifying records (rows), changing attributes (columns))?**
# In this specific case, we made adjustments like selecting specific rows and columns to focus on relevant data. We removed rows with null values to ensure data integrity. Additionally, we divided the data into training and testing sets, which is crucial for machine learning analysis. We also assigned attributes to variables for analysis, like 'x' and 'y', where 'x' contains independent variables, and 'y' holds the dependent variable for modeling. These adjustments are necessary to prepare the data for further analysis in Phase 4: Data modeling.
