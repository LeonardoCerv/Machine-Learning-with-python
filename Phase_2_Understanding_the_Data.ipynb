# %% [markdown]
# <a href="https://colab.research.google.com/github/OnyxDude/Machine-Learning-with-python/blob/main/Phase_2_Understanding_the_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')

# %%
df.head()
# Out:
#    Number Date (dd/mm/yy) Name of the activity   Cost  Budget  Time invested  \
# 0       1      08/14/2023     Public Transport   50.0   100.0           45.0
# 1       2      08/14/2023          Morning Jog    0.0     0.0           30.0
# 2       3      08/14/2023            Uber Ride   70.0   100.0           20.0
# 3       4      08/14/2023      Online Shopping  250.0   300.0           60.0
# 4       5      08/15/2023   Lunch with Friends  500.0   600.0           60.0
#
#    Type  Moment  No. of people
# 0   6.0     1.0            1.0
# 1   3.0     1.0            1.0
# 2   6.0     2.0            1.0
# 3   4.0     2.0            1.0
# 4   1.0     2.0            4.0

# %%
df.shape
# Out:
# (300, 9)

# %%
df.columns
# Out:
# Index(['Number', 'Date (dd/mm/yy)', 'Name of the activity', 'Cost', 'Budget',
#        'Time invested', 'Type', 'Moment', 'No. of people'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Number                    int64
# Date (dd/mm/yy)          object
# Name of the activity     object
# Cost                    float64
# Budget                  float64
# Time invested           float64
# Type                    float64
# Moment                  float64
# No. of people           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Number                300 non-null    int64
#  1   Date (dd/mm/yy)       186 non-null    object
#  2   Name of the activity  186 non-null    object
#  3   Cost                  186 non-null    float64
#  4   Budget                186 non-null    float64
#  5   Time invested         186 non-null    float64
#  6   Type                  186 non-null    float64
#  7   Moment                186 non-null    float64
#  8   No. of people         186 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 21.2+ KB

# %%
df["Cost"].sum()
# Out:
# 51090.0

# %%
df["Time invested"].sum()
# Out:
# 27680.0

# %%
df["Name of the activity"].value_counts()
# Out:
# Gardening            11
# Music Concert         9
# Movie Marathon        8
# Online Shopping       7
# Movie Night           7
#                      ..
# Basketball Game       1
# Museum Visit          1
# Evening Bike Ride     1
# Video Game            1
# Study Session         1
# Name: Name of the activity, Length: 66, dtype: int64

# %%
df["Moment"].value_counts()
# Out:
# 2.0    65
# 1.0    62
# 3.0    59
# Name: Moment, dtype: int64

# %%
df["No. of people"].value_counts()
# Out:
# 1.0     65
# 2.0     37
# 4.0     23
# 3.0     23
# 5.0     13
# 8.0      7
# 10.0     6
# 6.0      6
# 7.0      4
# 15.0     2
# Name: No. of people, dtype: int64

# %%
df.loc[df["Cost"].idxmax()]
# Out:
# Number                                  11
# Date (dd/mm/yy)                 08/16/2023
# Name of the activity    Savings Investment
# Cost                                5000.0
# Budget                              5000.0
# Time invested                         15.0
# Type                                   2.0
# Moment                                 2.0
# No. of people                          1.0
# Name: 10, dtype: object

# %%
df.groupby("Type").sum()
# Out:
# <ipython-input-15-081d2ae37dcd>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Type").sum()
#       Number     Cost   Budget  Time invested  Moment  No. of people
# Type
# 1.0     1228   5430.0   6750.0         1775.0    39.0           49.0
# 2.0     2113   8400.0   8950.0         3625.0    33.0           77.0
# 3.0     3739   3360.0   4710.0         4200.0    71.0           90.0
# 4.0     7832  30070.0  37700.0        14585.0   167.0          306.0
# 5.0     1899   1850.0   2500.0         2070.0    42.0           39.0
# 6.0      580   1980.0   2600.0         1425.0    17.0           14.0

# %%
df.describe()
# Out:
#            Number         Cost      Budget  Time invested        Type  \
# count  300.000000   186.000000   186.00000     186.000000  186.000000
# mean   150.500000   274.677419   339.83871     148.817204    3.505376
# std     86.746758   470.301977   509.55675     113.922444    1.253093
# min      1.000000     0.000000     0.00000      10.000000    1.000000
# 25%     75.750000    50.000000   100.00000      60.000000    3.000000
# 50%    150.500000   150.000000   200.00000     120.000000    4.000000
# 75%    225.250000   300.000000   350.00000     180.000000    4.000000
# max    300.000000  5000.000000  5000.00000     720.000000    6.000000
#
#            Moment  No. of people
# count  186.000000     186.000000
# mean     1.983871       3.091398
# std      0.808574       2.594637
# min      1.000000       1.000000
# 25%      1.000000       1.000000
# 50%      2.000000       2.000000
# 75%      3.000000       4.000000
# max      3.000000      15.000000
